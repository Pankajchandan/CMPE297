# %% [markdown]
# ### Improving the accuracy of the MNISTmodel.

# %%
import tensorflow as tf

# %%
# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.01
training_epochs = 10
batch_size = 100
display_step = 1
input_size = 784
output_size = 10

# %%
#keep probability
pkeep = tf.placeholder(tf.float32)
# tf Graph Input
x = tf.placeholder(tf.float32, [None, input_size]) # mnist data image of shape 28*28=784
y = tf.placeholder(tf.float32, [None, output_size]) # 0-9 digits recognition => 10 classes

# %%
dimensions = [200,100,60,30]
current_input = x
n_input = input_size

# We're going to keep every matrix we create so let's create a list to hold them all
Ws = []

# We'll create a for loop to create each layer:
for layer_i, n_output in enumerate(dimensions):

    # just like in the last session,
    # we'll use a variable scope to help encapsulate our variables
    # This will simply prefix all the variables made in this scope
    # with the name we give it.
    with tf.variable_scope("FC/layer/{}".format(layer_i),reuse=True):

        # Create a weight matrix which will increasingly reduce
        # down the amount of information in the input by performing
        # a matrix multiplication
        W = tf.get_variable(
            name='W',
            shape=[n_input, n_output],
            #initializer=tf.random_normal_initializer(mean=0.0, stddev=0.02)
            initializer = tf.contrib.layers.xavier_initializer(uniform=True, seed=None, dtype=tf.float32))
        
        B = tf.get_variable(
            name='B',
            shape=[n_output],
            #initializer=tf.random_normal_initializer(mean=0.0, stddev=0.02)
            initializer = tf.contrib.layers.xavier_initializer(uniform=True, seed=None, dtype=tf.float32))
        

        # Now we'll multiply our input by our newly created W matrix
        # and add the bias
        H = tf.nn.bias_add(
            name='H',
            value=tf.matmul(current_input, W),
            bias=B)

        # And then use a relu activation function on its output
        H  = tf.nn.relu(H)
        
        #add a dropout layer
        current_input = tf.nn.dropout(H,pkeep)

        # Finally we'll store the weight matrix so we can build the decoder.
        Ws.append(W)

        # We'll also replace n_input with the current n_output, so that on the
        # next iteration, our new number inputs will be correct.
        n_input = n_output
        
        print(current_input.get_shape().as_list())
# Out:
# [None, 200]
# [None, 100]
# [None, 60]
# [None, 30]

# %%
## we have our final layer
with tf.variable_scope("FCFinal", reuse=True):
    Wfinal = tf.get_variable(
            name='Wfinal',
            shape=[dimensions[-1], output_size],
            #shape=[input_size, output_size],
            #initializer=tf.random_normal_initializer(mean=0.0, stddev=0.02)
            initializer = tf.contrib.layers.xavier_initializer(uniform=True, seed=None, dtype=tf.float32))

    Bfinal = tf.get_variable(
            name='Bfinal',
            shape=[output_size],
            #initializer=tf.random_normal_initializer(mean=0.0, stddev=0.02)
            initializer = tf.contrib.layers.xavier_initializer(uniform=True, seed=None, dtype=tf.float32))

    logits = tf.nn.bias_add(
            name='logits',
            value=tf.matmul(current_input, Wfinal),
            #value = tf.matmul(x, Wfinal),
            bias=Bfinal)
 
    pred = tf.nn.softmax(logits) # Softmax 

tf.summary.histogram(“prediction”, pred)
print(pred.get_shape().as_list())
# Out:
# [None, 10]

# %%
with tf.variable_scope("FCoptimize", reuse=True):
    
    #cross entropy error
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
    tf.summary.histogram(“loss”, cost)
    
    #adamoptimizer
    optimizer =  tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %%
# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# %%
# no of correct prediction
correct_prediction = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
# Calculate accuracy
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
tf.summary.histogram(“accuracy”, accuracy)

# %%
sess = tf.Session()
# Run the initializer
sess.run(init)
#tensorboard writer
train_writer = tf.summary.FileWriter( './logs/1/train ', sess.graph)
counter=0
# Training cycle
for epoch in range(training_epochs):
    avg_cost = 0.
    total_batch = int(mnist.train.num_examples/batch_size)
    # Loop over all batches
    for i in range(total_batch):
        counter+=1
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        #merge summary
        merge = tf.summary.merge_all()
        # Run optimization op (backprop) and cost op (to get loss value)
        summary, _, c = sess.run([summary, optimizer, cost], feed_dict={x: batch_xs,
                                                          y: batch_ys, pkeep: 1.0})
        # Compute average loss
        avg_cost += c / total_batch
        train_writer.add_summary(summary, counter)
    # Display logs per epoch step
    if (epoch+1) % display_step == 0:
        print("Epoch:", '%04d' % (epoch+1), "cost= ",(avg_cost))
        acc = sess.run(accuracy,feed_dict = {x: batch_xs, y: batch_ys, pkeep: 1.0})
        print ("accuracy = ",acc)
        ##print("Accuracy:", acc.eval(sesion = sess))

print("Optimization Finished!")
# Out:
# Epoch: 0001 cost=  0.295105299249
# accuracy =  0.92
# Epoch: 0002 cost=  0.144752108285
# accuracy =  0.94
# Epoch: 0003 cost=  0.114285484256
# accuracy =  0.99
# Epoch: 0004 cost=  0.10342528116
# accuracy =  0.99
# Epoch: 0005 cost=  0.0962027393781
# accuracy =  0.99
# Epoch: 0006 cost=  0.0899489679738
# accuracy =  0.96
# Epoch: 0007 cost=  0.0819457255274
# accuracy =  0.98
# Epoch: 0008 cost=  0.0761767299621
# accuracy =  0.96
# Epoch: 0009 cost=  0.0747211394122
# accuracy =  0.99
# Epoch: 0010 cost=  0.0707066442379
# accuracy =  0.98
# Optimization Finished!

# %%
##run it on test Set
acc1 = sess.run(accuracy,feed_dict = {x: mnist.test.images, 
                                      y: mnist.test.labels, pkeep: 1.0})
print ("accuracy on test set: ",acc1)
# Out:
# accuracy on test set:  0.9722

# %%
##this is my graph
g = tf.get_default_graph()
[op.name for op in g.get_operations()]
# Out:
# ['Placeholder',
#  'Placeholder_1',
#  'Placeholder_2',
#  'FC/layer/0/W/Initializer/random_uniform/shape',
#  'FC/layer/0/W/Initializer/random_uniform/min',
#  'FC/layer/0/W/Initializer/random_uniform/max',
#  'FC/layer/0/W/Initializer/random_uniform/RandomUniform',
#  'FC/layer/0/W/Initializer/random_uniform/sub',
#  'FC/layer/0/W/Initializer/random_uniform/mul',
#  'FC/layer/0/W/Initializer/random_uniform',
#  'FC/layer/0/W',
#  'FC/layer/0/W/Assign',
#  'FC/layer/0/W/read',
#  'FC/layer/0/B/Initializer/random_uniform/shape',
#  'FC/layer/0/B/Initializer/random_uniform/min',
#  'FC/layer/0/B/Initializer/random_uniform/max',
#  'FC/layer/0/B/Initializer/random_uniform/RandomUniform',
#  'FC/layer/0/B/Initializer/random_uniform/sub',
#  'FC/layer/0/B/Initializer/random_uniform/mul',
#  'FC/layer/0/B/Initializer/random_uniform',
#  'FC/layer/0/B',
#  'FC/layer/0/B/Assign',
#  'FC/layer/0/B/read',
#  'FC/layer/0/MatMul',
#  'FC/layer/0/H',
#  'FC/layer/0/Relu',
#  'FC/layer/0/dropout/Shape',
#  'FC/layer/0/dropout/random_uniform/min',
#  'FC/layer/0/dropout/random_uniform/max',
#  'FC/layer/0/dropout/random_uniform/RandomUniform',
#  'FC/layer/0/dropout/random_uniform/sub',
#  'FC/layer/0/dropout/random_uniform/mul',
#  'FC/layer/0/dropout/random_uniform',
#  'FC/layer/0/dropout/add',
#  'FC/layer/0/dropout/Floor',
#  'FC/layer/0/dropout/div',
#  'FC/layer/0/dropout/mul',
#  'FC/layer/1/W/Initializer/random_uniform/shape',
#  'FC/layer/1/W/Initializer/random_uniform/min',
#  'FC/layer/1/W/Initializer/random_uniform/max',
#  'FC/layer/1/W/Initializer/random_uniform/RandomUniform',
#  'FC/layer/1/W/Initializer/random_uniform/sub',
#  'FC/layer/1/W/Initializer/random_uniform/mul',
#  'FC/layer/1/W/Initializer/random_uniform',
#  'FC/layer/1/W',
#  'FC/layer/1/W/Assign',
#  'FC/layer/1/W/read',
#  'FC/layer/1/B/Initializer/random_uniform/shape',
#  'FC/layer/1/B/Initializer/random_uniform/min',
#  'FC/layer/1/B/Initializer/random_uniform/max',
#  'FC/layer/1/B/Initializer/random_uniform/RandomUniform',
#  'FC/layer/1/B/Initializer/random_uniform/sub',
#  'FC/layer/1/B/Initializer/random_uniform/mul',
#  'FC/layer/1/B/Initializer/random_uniform',
#  'FC/layer/1/B',
#  'FC/layer/1/B/Assign',
#  'FC/layer/1/B/read',
#  'FC/layer/1/MatMul',
#  'FC/layer/1/H',
#  'FC/layer/1/Relu',
#  'FC/layer/1/dropout/Shape',
#  'FC/layer/1/dropout/random_uniform/min',
#  'FC/layer/1/dropout/random_uniform/max',
#  'FC/layer/1/dropout/random_uniform/RandomUniform',
#  'FC/layer/1/dropout/random_uniform/sub',
#  'FC/layer/1/dropout/random_uniform/mul',
#  'FC/layer/1/dropout/random_uniform',
#  'FC/layer/1/dropout/add',
#  'FC/layer/1/dropout/Floor',
#  'FC/layer/1/dropout/div',
#  'FC/layer/1/dropout/mul',
#  'FC/layer/2/W/Initializer/random_uniform/shape',
#  'FC/layer/2/W/Initializer/random_uniform/min',
#  'FC/layer/2/W/Initializer/random_uniform/max',
#  'FC/layer/2/W/Initializer/random_uniform/RandomUniform',
#  'FC/layer/2/W/Initializer/random_uniform/sub',
#  'FC/layer/2/W/Initializer/random_uniform/mul',
#  'FC/layer/2/W/Initializer/random_uniform',
#  'FC/layer/2/W',
#  'FC/layer/2/W/Assign',
#  'FC/layer/2/W/read',
#  'FC/layer/2/B/Initializer/random_uniform/shape',
#  'FC/layer/2/B/Initializer/random_uniform/min',
#  'FC/layer/2/B/Initializer/random_uniform/max',
#  'FC/layer/2/B/Initializer/random_uniform/RandomUniform',
#  'FC/layer/2/B/Initializer/random_uniform/sub',
#  'FC/layer/2/B/Initializer/random_uniform/mul',
#  'FC/layer/2/B/Initializer/random_uniform',
#  'FC/layer/2/B',
#  'FC/layer/2/B/Assign',
#  'FC/layer/2/B/read',
#  'FC/layer/2/MatMul',
#  'FC/layer/2/H',
#  'FC/layer/2/Relu',
#  'FC/layer/2/dropout/Shape',
#  'FC/layer/2/dropout/random_uniform/min',
#  'FC/layer/2/dropout/random_uniform/max',
#  'FC/layer/2/dropout/random_uniform/RandomUniform',
#  'FC/layer/2/dropout/random_uniform/sub',
#  'FC/layer/2/dropout/random_uniform/mul',
#  'FC/layer/2/dropout/random_uniform',
#  'FC/layer/2/dropout/add',
#  'FC/layer/2/dropout/Floor',
#  'FC/layer/2/dropout/div',
#  'FC/layer/2/dropout/mul',
#  'FC/layer/3/W/Initializer/random_uniform/shape',
#  'FC/layer/3/W/Initializer/random_uniform/min',
#  'FC/layer/3/W/Initializer/random_uniform/max',
#  'FC/layer/3/W/Initializer/random_uniform/RandomUniform',
#  'FC/layer/3/W/Initializer/random_uniform/sub',
#  'FC/layer/3/W/Initializer/random_uniform/mul',
#  'FC/layer/3/W/Initializer/random_uniform',
#  'FC/layer/3/W',
#  'FC/layer/3/W/Assign',
#  'FC/layer/3/W/read',
#  'FC/layer/3/B/Initializer/random_uniform/shape',
#  'FC/layer/3/B/Initializer/random_uniform/min',
#  'FC/layer/3/B/Initializer/random_uniform/max',
#  'FC/layer/3/B/Initializer/random_uniform/RandomUniform',
#  'FC/layer/3/B/Initializer/random_uniform/sub',
#  'FC/layer/3/B/Initializer/random_uniform/mul',
#  'FC/layer/3/B/Initializer/random_uniform',
#  'FC/layer/3/B',
#  'FC/layer/3/B/Assign',
#  'FC/layer/3/B/read',
#  'FC/layer/3/MatMul',
#  'FC/layer/3/H',
#  'FC/layer/3/Relu',
#  'FC/layer/3/dropout/Shape',
#  'FC/layer/3/dropout/random_uniform/min',
#  'FC/layer/3/dropout/random_uniform/max',
#  'FC/layer/3/dropout/random_uniform/RandomUniform',
#  'FC/layer/3/dropout/random_uniform/sub',
#  'FC/layer/3/dropout/random_uniform/mul',
#  'FC/layer/3/dropout/random_uniform',
#  'FC/layer/3/dropout/add',
#  'FC/layer/3/dropout/Floor',
#  'FC/layer/3/dropout/div',
#  'FC/layer/3/dropout/mul',
#  'FCFinal/Wfinal/Initializer/random_uniform/shape',
#  'FCFinal/Wfinal/Initializer/random_uniform/min',
#  'FCFinal/Wfinal/Initializer/random_uniform/max',
#  'FCFinal/Wfinal/Initializer/random_uniform/RandomUniform',
#  'FCFinal/Wfinal/Initializer/random_uniform/sub',
#  'FCFinal/Wfinal/Initializer/random_uniform/mul',
#  'FCFinal/Wfinal/Initializer/random_uniform',
#  'FCFinal/Wfinal',
#  'FCFinal/Wfinal/Assign',
#  'FCFinal/Wfinal/read',
#  'FCFinal/Bfinal/Initializer/random_uniform/shape',
#  'FCFinal/Bfinal/Initializer/random_uniform/min',
#  'FCFinal/Bfinal/Initializer/random_uniform/max',
#  'FCFinal/Bfinal/Initializer/random_uniform/RandomUniform',
#  'FCFinal/Bfinal/Initializer/random_uniform/sub',
#  'FCFinal/Bfinal/Initializer/random_uniform/mul',
#  'FCFinal/Bfinal/Initializer/random_uniform',
#  'FCFinal/Bfinal',
#  'FCFinal/Bfinal/Assign',
#  'FCFinal/Bfinal/read',
#  'FCFinal/MatMul',
#  'FCFinal/logits',
#  'FCFinal/Softmax',
#  'FCoptimize/Rank',
#  'FCoptimize/Shape',
#  'FCoptimize/Rank_1',
#  'FCoptimize/Shape_1',
#  'FCoptimize/Sub/y',
#  'FCoptimize/Sub',
#  'FCoptimize/Slice/begin',
#  'FCoptimize/Slice/size',
#  'FCoptimize/Slice',
#  'FCoptimize/concat/values_0',
#  'FCoptimize/concat/axis',
#  'FCoptimize/concat',
#  'FCoptimize/Reshape',
#  'FCoptimize/Rank_2',
#  'FCoptimize/Shape_2',
#  'FCoptimize/Sub_1/y',
#  'FCoptimize/Sub_1',
#  'FCoptimize/Slice_1/begin',
#  'FCoptimize/Slice_1/size',
#  'FCoptimize/Slice_1',
#  'FCoptimize/concat_1/values_0',
#  'FCoptimize/concat_1/axis',
#  'FCoptimize/concat_1',
#  'FCoptimize/Reshape_1',
#  'FCoptimize/SoftmaxCrossEntropyWithLogits',
#  'FCoptimize/Sub_2/y',
#  'FCoptimize/Sub_2',
#  'FCoptimize/Slice_2/begin',
#  'FCoptimize/Slice_2/size',
#  'FCoptimize/Slice_2',
#  'FCoptimize/Reshape_2',
#  'FCoptimize/Const',
#  'FCoptimize/Mean',
#  'FCoptimize/gradients/Shape',
#  'FCoptimize/gradients/Const',
#  'FCoptimize/gradients/Fill',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Reshape/shape',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Reshape',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Shape',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Tile',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Shape_1',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Shape_2',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Const',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Prod',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Const_1',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Prod_1',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Maximum/y',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Maximum',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/floordiv',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/Cast',
#  'FCoptimize/gradients/FCoptimize/Mean_grad/truediv',
#  'FCoptimize/gradients/FCoptimize/Reshape_2_grad/Shape',
#  'FCoptimize/gradients/FCoptimize/Reshape_2_grad/Reshape',
#  'FCoptimize/gradients/zeros_like',
#  'FCoptimize/gradients/FCoptimize/SoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim',
#  'FCoptimize/gradients/FCoptimize/SoftmaxCrossEntropyWithLogits_grad/ExpandDims',
#  'FCoptimize/gradients/FCoptimize/SoftmaxCrossEntropyWithLogits_grad/mul',
#  'FCoptimize/gradients/FCoptimize/Reshape_grad/Shape',
#  'FCoptimize/gradients/FCoptimize/Reshape_grad/Reshape',
#  'FCoptimize/gradients/FCFinal/logits_grad/BiasAddGrad',
#  'FCoptimize/gradients/FCFinal/logits_grad/tuple/group_deps',
#  'FCoptimize/gradients/FCFinal/logits_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FCFinal/logits_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FCFinal/MatMul_grad/MatMul',
#  'FCoptimize/gradients/FCFinal/MatMul_grad/MatMul_1',
#  'FCoptimize/gradients/FCFinal/MatMul_grad/tuple/group_deps',
#  'FCoptimize/gradients/FCFinal/MatMul_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FCFinal/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/Shape',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/Shape_1',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/mul',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/Sum',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/Reshape',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/mul_1',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/Sum_1',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/Reshape_1',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/3/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/Shape',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/Shape_1',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/RealDiv',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/Sum',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/Reshape',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/Neg',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/RealDiv_1',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/RealDiv_2',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/mul',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/Sum_1',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/Reshape_1',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/3/dropout/div_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/3/Relu_grad/ReluGrad',
#  'FCoptimize/gradients/FC/layer/3/H_grad/BiasAddGrad',
#  'FCoptimize/gradients/FC/layer/3/H_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/3/H_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/3/H_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/3/MatMul_grad/MatMul',
#  'FCoptimize/gradients/FC/layer/3/MatMul_grad/MatMul_1',
#  'FCoptimize/gradients/FC/layer/3/MatMul_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/3/MatMul_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/3/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/Shape',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/Shape_1',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/mul',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/Sum',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/Reshape',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/mul_1',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/Sum_1',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/Reshape_1',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/2/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/Shape',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/Shape_1',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/RealDiv',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/Sum',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/Reshape',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/Neg',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/RealDiv_1',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/RealDiv_2',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/mul',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/Sum_1',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/Reshape_1',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/2/dropout/div_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/2/Relu_grad/ReluGrad',
#  'FCoptimize/gradients/FC/layer/2/H_grad/BiasAddGrad',
#  'FCoptimize/gradients/FC/layer/2/H_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/2/H_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/2/H_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/2/MatMul_grad/MatMul',
#  'FCoptimize/gradients/FC/layer/2/MatMul_grad/MatMul_1',
#  'FCoptimize/gradients/FC/layer/2/MatMul_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/2/MatMul_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/2/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/Shape',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/Shape_1',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/mul',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/Sum',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/Reshape',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/mul_1',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/Sum_1',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/Reshape_1',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/1/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/Shape',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/Shape_1',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/RealDiv',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/Sum',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/Reshape',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/Neg',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/RealDiv_1',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/RealDiv_2',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/mul',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/Sum_1',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/Reshape_1',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/1/dropout/div_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/1/Relu_grad/ReluGrad',
#  'FCoptimize/gradients/FC/layer/1/H_grad/BiasAddGrad',
#  'FCoptimize/gradients/FC/layer/1/H_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/1/H_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/1/H_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/1/MatMul_grad/MatMul',
#  'FCoptimize/gradients/FC/layer/1/MatMul_grad/MatMul_1',
#  'FCoptimize/gradients/FC/layer/1/MatMul_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/1/MatMul_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/1/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/Shape',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/Shape_1',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/mul',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/Sum',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/Reshape',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/mul_1',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/Sum_1',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/Reshape_1',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/0/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/Shape',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/Shape_1',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/RealDiv',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/Sum',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/Reshape',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/Neg',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/RealDiv_1',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/RealDiv_2',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/mul',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/Sum_1',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/Reshape_1',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/0/dropout/div_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/0/Relu_grad/ReluGrad',
#  'FCoptimize/gradients/FC/layer/0/H_grad/BiasAddGrad',
#  'FCoptimize/gradients/FC/layer/0/H_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/0/H_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/0/H_grad/tuple/control_dependency_1',
#  'FCoptimize/gradients/FC/layer/0/MatMul_grad/MatMul',
#  'FCoptimize/gradients/FC/layer/0/MatMul_grad/MatMul_1',
#  'FCoptimize/gradients/FC/layer/0/MatMul_grad/tuple/group_deps',
#  'FCoptimize/gradients/FC/layer/0/MatMul_grad/tuple/control_dependency',
#  'FCoptimize/gradients/FC/layer/0/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize/beta1_power/initial_value',
#  'FCoptimize/beta1_power',
#  'FCoptimize/beta1_power/Assign',
#  'FCoptimize/beta1_power/read',
#  'FCoptimize/beta2_power/initial_value',
#  'FCoptimize/beta2_power',
#  'FCoptimize/beta2_power/Assign',
#  'FCoptimize/beta2_power/read',
#  'FCoptimize/FC/layer/0/W/Adam/Initializer/zeros',
#  'FCoptimize/FC/layer/0/W/Adam',
#  'FCoptimize/FC/layer/0/W/Adam/Assign',
#  'FCoptimize/FC/layer/0/W/Adam/read',
#  'FCoptimize/FC/layer/0/W/Adam_1/Initializer/zeros',
#  'FCoptimize/FC/layer/0/W/Adam_1',
#  'FCoptimize/FC/layer/0/W/Adam_1/Assign',
#  'FCoptimize/FC/layer/0/W/Adam_1/read',
#  'FCoptimize/FC/layer/0/B/Adam/Initializer/zeros',
#  'FCoptimize/FC/layer/0/B/Adam',
#  'FCoptimize/FC/layer/0/B/Adam/Assign',
#  'FCoptimize/FC/layer/0/B/Adam/read',
#  'FCoptimize/FC/layer/0/B/Adam_1/Initializer/zeros',
#  'FCoptimize/FC/layer/0/B/Adam_1',
#  'FCoptimize/FC/layer/0/B/Adam_1/Assign',
#  'FCoptimize/FC/layer/0/B/Adam_1/read',
#  'FCoptimize/FC/layer/1/W/Adam/Initializer/zeros',
#  'FCoptimize/FC/layer/1/W/Adam',
#  'FCoptimize/FC/layer/1/W/Adam/Assign',
#  'FCoptimize/FC/layer/1/W/Adam/read',
#  'FCoptimize/FC/layer/1/W/Adam_1/Initializer/zeros',
#  'FCoptimize/FC/layer/1/W/Adam_1',
#  'FCoptimize/FC/layer/1/W/Adam_1/Assign',
#  'FCoptimize/FC/layer/1/W/Adam_1/read',
#  'FCoptimize/FC/layer/1/B/Adam/Initializer/zeros',
#  'FCoptimize/FC/layer/1/B/Adam',
#  'FCoptimize/FC/layer/1/B/Adam/Assign',
#  'FCoptimize/FC/layer/1/B/Adam/read',
#  'FCoptimize/FC/layer/1/B/Adam_1/Initializer/zeros',
#  'FCoptimize/FC/layer/1/B/Adam_1',
#  'FCoptimize/FC/layer/1/B/Adam_1/Assign',
#  'FCoptimize/FC/layer/1/B/Adam_1/read',
#  'FCoptimize/FC/layer/2/W/Adam/Initializer/zeros',
#  'FCoptimize/FC/layer/2/W/Adam',
#  'FCoptimize/FC/layer/2/W/Adam/Assign',
#  'FCoptimize/FC/layer/2/W/Adam/read',
#  'FCoptimize/FC/layer/2/W/Adam_1/Initializer/zeros',
#  'FCoptimize/FC/layer/2/W/Adam_1',
#  'FCoptimize/FC/layer/2/W/Adam_1/Assign',
#  'FCoptimize/FC/layer/2/W/Adam_1/read',
#  'FCoptimize/FC/layer/2/B/Adam/Initializer/zeros',
#  'FCoptimize/FC/layer/2/B/Adam',
#  'FCoptimize/FC/layer/2/B/Adam/Assign',
#  'FCoptimize/FC/layer/2/B/Adam/read',
#  'FCoptimize/FC/layer/2/B/Adam_1/Initializer/zeros',
#  'FCoptimize/FC/layer/2/B/Adam_1',
#  'FCoptimize/FC/layer/2/B/Adam_1/Assign',
#  'FCoptimize/FC/layer/2/B/Adam_1/read',
#  'FCoptimize/FC/layer/3/W/Adam/Initializer/zeros',
#  'FCoptimize/FC/layer/3/W/Adam',
#  'FCoptimize/FC/layer/3/W/Adam/Assign',
#  'FCoptimize/FC/layer/3/W/Adam/read',
#  'FCoptimize/FC/layer/3/W/Adam_1/Initializer/zeros',
#  'FCoptimize/FC/layer/3/W/Adam_1',
#  'FCoptimize/FC/layer/3/W/Adam_1/Assign',
#  'FCoptimize/FC/layer/3/W/Adam_1/read',
#  'FCoptimize/FC/layer/3/B/Adam/Initializer/zeros',
#  'FCoptimize/FC/layer/3/B/Adam',
#  'FCoptimize/FC/layer/3/B/Adam/Assign',
#  'FCoptimize/FC/layer/3/B/Adam/read',
#  'FCoptimize/FC/layer/3/B/Adam_1/Initializer/zeros',
#  'FCoptimize/FC/layer/3/B/Adam_1',
#  'FCoptimize/FC/layer/3/B/Adam_1/Assign',
#  'FCoptimize/FC/layer/3/B/Adam_1/read',
#  'FCoptimize/FCFinal/Wfinal/Adam/Initializer/zeros',
#  'FCoptimize/FCFinal/Wfinal/Adam',
#  'FCoptimize/FCFinal/Wfinal/Adam/Assign',
#  'FCoptimize/FCFinal/Wfinal/Adam/read',
#  'FCoptimize/FCFinal/Wfinal/Adam_1/Initializer/zeros',
#  'FCoptimize/FCFinal/Wfinal/Adam_1',
#  'FCoptimize/FCFinal/Wfinal/Adam_1/Assign',
#  'FCoptimize/FCFinal/Wfinal/Adam_1/read',
#  'FCoptimize/FCFinal/Bfinal/Adam/Initializer/zeros',
#  'FCoptimize/FCFinal/Bfinal/Adam',
#  'FCoptimize/FCFinal/Bfinal/Adam/Assign',
#  'FCoptimize/FCFinal/Bfinal/Adam/read',
#  'FCoptimize/FCFinal/Bfinal/Adam_1/Initializer/zeros',
#  'FCoptimize/FCFinal/Bfinal/Adam_1',
#  'FCoptimize/FCFinal/Bfinal/Adam_1/Assign',
#  'FCoptimize/FCFinal/Bfinal/Adam_1/read',
#  'FCoptimize/Adam/learning_rate',
#  'FCoptimize/Adam/beta1',
#  'FCoptimize/Adam/beta2',
#  'FCoptimize/Adam/epsilon',
#  'FCoptimize/Adam/update_FC/layer/0/W/ApplyAdam',
#  'FCoptimize/Adam/update_FC/layer/0/B/ApplyAdam',
#  'FCoptimize/Adam/update_FC/layer/1/W/ApplyAdam',
#  'FCoptimize/Adam/update_FC/layer/1/B/ApplyAdam',
#  'FCoptimize/Adam/update_FC/layer/2/W/ApplyAdam',
#  'FCoptimize/Adam/update_FC/layer/2/B/ApplyAdam',
#  'FCoptimize/Adam/update_FC/layer/3/W/ApplyAdam',
#  'FCoptimize/Adam/update_FC/layer/3/B/ApplyAdam',
#  'FCoptimize/Adam/update_FCFinal/Wfinal/ApplyAdam',
#  'FCoptimize/Adam/update_FCFinal/Bfinal/ApplyAdam',
#  'FCoptimize/Adam/mul',
#  'FCoptimize/Adam/Assign',
#  'FCoptimize/Adam/mul_1',
#  'FCoptimize/Adam/Assign_1',
#  'FCoptimize/Adam',
#  'init',
#  'ArgMax/dimension',
#  'ArgMax',
#  'ArgMax_1/dimension',
#  'ArgMax_1',
#  'Equal',
#  'Cast',
#  'Const',
#  'Mean',
#  'init_1',
#  'ArgMax_2/dimension',
#  'ArgMax_2',
#  'ArgMax_3/dimension',
#  'ArgMax_3',
#  'Equal_1',
#  'Cast_1',
#  'Const_1',
#  'Mean_1',
#  'init_2',
#  'ArgMax_4/dimension',
#  'ArgMax_4',
#  'ArgMax_5/dimension',
#  'ArgMax_5',
#  'Equal_2',
#  'Cast_2',
#  'Const_2',
#  'Mean_2',
#  'init_3',
#  'ArgMax_6/dimension',
#  'ArgMax_6',
#  'ArgMax_7/dimension',
#  'ArgMax_7',
#  'Equal_3',
#  'Cast_3',
#  'Const_3',
#  'Mean_3',
#  'FCoptimize_1/Rank',
#  'FCoptimize_1/Shape',
#  'FCoptimize_1/Rank_1',
#  'FCoptimize_1/Shape_1',
#  'FCoptimize_1/Sub/y',
#  'FCoptimize_1/Sub',
#  'FCoptimize_1/Slice/begin',
#  'FCoptimize_1/Slice/size',
#  'FCoptimize_1/Slice',
#  'FCoptimize_1/concat/values_0',
#  'FCoptimize_1/concat/axis',
#  'FCoptimize_1/concat',
#  'FCoptimize_1/Reshape',
#  'FCoptimize_1/Rank_2',
#  'FCoptimize_1/Shape_2',
#  'FCoptimize_1/Sub_1/y',
#  'FCoptimize_1/Sub_1',
#  'FCoptimize_1/Slice_1/begin',
#  'FCoptimize_1/Slice_1/size',
#  'FCoptimize_1/Slice_1',
#  'FCoptimize_1/concat_1/values_0',
#  'FCoptimize_1/concat_1/axis',
#  'FCoptimize_1/concat_1',
#  'FCoptimize_1/Reshape_1',
#  'FCoptimize_1/SoftmaxCrossEntropyWithLogits',
#  'FCoptimize_1/Sub_2/y',
#  'FCoptimize_1/Sub_2',
#  'FCoptimize_1/Slice_2/begin',
#  'FCoptimize_1/Slice_2/size',
#  'FCoptimize_1/Slice_2',
#  'FCoptimize_1/Reshape_2',
#  'FCoptimize_1/Const',
#  'FCoptimize_1/Mean',
#  'FCoptimize_1/gradients/Shape',
#  'FCoptimize_1/gradients/Const',
#  'FCoptimize_1/gradients/Fill',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Reshape/shape',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Reshape',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Shape',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Tile',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Shape_1',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Shape_2',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Const',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Prod',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Const_1',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Prod_1',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Maximum/y',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Maximum',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/floordiv',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/Cast',
#  'FCoptimize_1/gradients/FCoptimize_1/Mean_grad/truediv',
#  'FCoptimize_1/gradients/FCoptimize_1/Reshape_2_grad/Shape',
#  'FCoptimize_1/gradients/FCoptimize_1/Reshape_2_grad/Reshape',
#  'FCoptimize_1/gradients/zeros_like',
#  'FCoptimize_1/gradients/FCoptimize_1/SoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim',
#  'FCoptimize_1/gradients/FCoptimize_1/SoftmaxCrossEntropyWithLogits_grad/ExpandDims',
#  'FCoptimize_1/gradients/FCoptimize_1/SoftmaxCrossEntropyWithLogits_grad/mul',
#  'FCoptimize_1/gradients/FCoptimize_1/Reshape_grad/Shape',
#  'FCoptimize_1/gradients/FCoptimize_1/Reshape_grad/Reshape',
#  'FCoptimize_1/gradients/FCFinal/logits_grad/BiasAddGrad',
#  'FCoptimize_1/gradients/FCFinal/logits_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FCFinal/logits_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FCFinal/logits_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FCFinal/MatMul_grad/MatMul',
#  'FCoptimize_1/gradients/FCFinal/MatMul_grad/MatMul_1',
#  'FCoptimize_1/gradients/FCFinal/MatMul_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FCFinal/MatMul_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FCFinal/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/Shape',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/Shape_1',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/mul',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/Sum',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/Reshape',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/mul_1',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/Sum_1',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/Reshape_1',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/Shape',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/Shape_1',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/RealDiv',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/Sum',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/Reshape',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/Neg',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/RealDiv_1',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/RealDiv_2',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/mul',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/Sum_1',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/Reshape_1',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/3/dropout/div_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/3/Relu_grad/ReluGrad',
#  'FCoptimize_1/gradients/FC/layer/3/H_grad/BiasAddGrad',
#  'FCoptimize_1/gradients/FC/layer/3/H_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/3/H_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/3/H_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/3/MatMul_grad/MatMul',
#  'FCoptimize_1/gradients/FC/layer/3/MatMul_grad/MatMul_1',
#  'FCoptimize_1/gradients/FC/layer/3/MatMul_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/3/MatMul_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/3/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/Shape',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/Shape_1',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/mul',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/Sum',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/Reshape',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/mul_1',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/Sum_1',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/Reshape_1',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/Shape',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/Shape_1',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/RealDiv',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/Sum',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/Reshape',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/Neg',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/RealDiv_1',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/RealDiv_2',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/mul',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/Sum_1',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/Reshape_1',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/2/dropout/div_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/2/Relu_grad/ReluGrad',
#  'FCoptimize_1/gradients/FC/layer/2/H_grad/BiasAddGrad',
#  'FCoptimize_1/gradients/FC/layer/2/H_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/2/H_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/2/H_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/2/MatMul_grad/MatMul',
#  'FCoptimize_1/gradients/FC/layer/2/MatMul_grad/MatMul_1',
#  'FCoptimize_1/gradients/FC/layer/2/MatMul_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/2/MatMul_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/2/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/Shape',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/Shape_1',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/mul',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/Sum',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/Reshape',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/mul_1',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/Sum_1',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/Reshape_1',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/Shape',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/Shape_1',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/RealDiv',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/Sum',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/Reshape',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/Neg',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/RealDiv_1',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/RealDiv_2',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/mul',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/Sum_1',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/Reshape_1',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/1/dropout/div_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/1/Relu_grad/ReluGrad',
#  'FCoptimize_1/gradients/FC/layer/1/H_grad/BiasAddGrad',
#  'FCoptimize_1/gradients/FC/layer/1/H_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/1/H_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/1/H_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/1/MatMul_grad/MatMul',
#  'FCoptimize_1/gradients/FC/layer/1/MatMul_grad/MatMul_1',
#  'FCoptimize_1/gradients/FC/layer/1/MatMul_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/1/MatMul_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/1/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/Shape',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/Shape_1',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/mul',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/Sum',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/Reshape',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/mul_1',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/Sum_1',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/Reshape_1',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/Shape',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/Shape_1',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/RealDiv',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/Sum',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/Reshape',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/Neg',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/RealDiv_1',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/RealDiv_2',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/mul',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/Sum_1',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/Reshape_1',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/0/dropout/div_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/0/Relu_grad/ReluGrad',
#  'FCoptimize_1/gradients/FC/layer/0/H_grad/BiasAddGrad',
#  'FCoptimize_1/gradients/FC/layer/0/H_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/0/H_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/0/H_grad/tuple/control_dependency_1',
#  'FCoptimize_1/gradients/FC/layer/0/MatMul_grad/MatMul',
#  'FCoptimize_1/gradients/FC/layer/0/MatMul_grad/MatMul_1',
#  'FCoptimize_1/gradients/FC/layer/0/MatMul_grad/tuple/group_deps',
#  'FCoptimize_1/gradients/FC/layer/0/MatMul_grad/tuple/control_dependency',
#  'FCoptimize_1/gradients/FC/layer/0/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize_1/beta1_power/initial_value',
#  'FCoptimize_1/beta1_power',
#  'FCoptimize_1/beta1_power/Assign',
#  'FCoptimize_1/beta1_power/read',
#  'FCoptimize_1/beta2_power/initial_value',
#  'FCoptimize_1/beta2_power',
#  'FCoptimize_1/beta2_power/Assign',
#  'FCoptimize_1/beta2_power/read',
#  'FCoptimize_1/Adam/learning_rate',
#  'FCoptimize_1/Adam/beta1',
#  'FCoptimize_1/Adam/beta2',
#  'FCoptimize_1/Adam/epsilon',
#  'FCoptimize_1/Adam/update_FC/layer/0/W/ApplyAdam',
#  'FCoptimize_1/Adam/update_FC/layer/0/B/ApplyAdam',
#  'FCoptimize_1/Adam/update_FC/layer/1/W/ApplyAdam',
#  'FCoptimize_1/Adam/update_FC/layer/1/B/ApplyAdam',
#  'FCoptimize_1/Adam/update_FC/layer/2/W/ApplyAdam',
#  'FCoptimize_1/Adam/update_FC/layer/2/B/ApplyAdam',
#  'FCoptimize_1/Adam/update_FC/layer/3/W/ApplyAdam',
#  'FCoptimize_1/Adam/update_FC/layer/3/B/ApplyAdam',
#  'FCoptimize_1/Adam/update_FCFinal/Wfinal/ApplyAdam',
#  'FCoptimize_1/Adam/update_FCFinal/Bfinal/ApplyAdam',
#  'FCoptimize_1/Adam/mul',
#  'FCoptimize_1/Adam/Assign',
#  'FCoptimize_1/Adam/mul_1',
#  'FCoptimize_1/Adam/Assign_1',
#  'FCoptimize_1/Adam',
#  'init_4',
#  'ArgMax_8/dimension',
#  'ArgMax_8',
#  'ArgMax_9/dimension',
#  'ArgMax_9',
#  'Equal_4',
#  'Cast_4',
#  'Const_4',
#  'Mean_4',
#  'Placeholder_3',
#  'Placeholder_4',
#  'Placeholder_5',
#  'FC/layer/0_1/MatMul',
#  'FC/layer/0_1/H',
#  'FC/layer/0_1/Relu',
#  'FC/layer/0_1/dropout/Shape',
#  'FC/layer/0_1/dropout/random_uniform/min',
#  'FC/layer/0_1/dropout/random_uniform/max',
#  'FC/layer/0_1/dropout/random_uniform/RandomUniform',
#  'FC/layer/0_1/dropout/random_uniform/sub',
#  'FC/layer/0_1/dropout/random_uniform/mul',
#  'FC/layer/0_1/dropout/random_uniform',
#  'FC/layer/0_1/dropout/add',
#  'FC/layer/0_1/dropout/Floor',
#  'FC/layer/0_1/dropout/div',
#  'FC/layer/0_1/dropout/mul',
#  'FC/layer/1_1/MatMul',
#  'FC/layer/1_1/H',
#  'FC/layer/1_1/Relu',
#  'FC/layer/1_1/dropout/Shape',
#  'FC/layer/1_1/dropout/random_uniform/min',
#  'FC/layer/1_1/dropout/random_uniform/max',
#  'FC/layer/1_1/dropout/random_uniform/RandomUniform',
#  'FC/layer/1_1/dropout/random_uniform/sub',
#  'FC/layer/1_1/dropout/random_uniform/mul',
#  'FC/layer/1_1/dropout/random_uniform',
#  'FC/layer/1_1/dropout/add',
#  'FC/layer/1_1/dropout/Floor',
#  'FC/layer/1_1/dropout/div',
#  'FC/layer/1_1/dropout/mul',
#  'FC/layer/2_1/MatMul',
#  'FC/layer/2_1/H',
#  'FC/layer/2_1/Relu',
#  'FC/layer/2_1/dropout/Shape',
#  'FC/layer/2_1/dropout/random_uniform/min',
#  'FC/layer/2_1/dropout/random_uniform/max',
#  'FC/layer/2_1/dropout/random_uniform/RandomUniform',
#  'FC/layer/2_1/dropout/random_uniform/sub',
#  'FC/layer/2_1/dropout/random_uniform/mul',
#  'FC/layer/2_1/dropout/random_uniform',
#  'FC/layer/2_1/dropout/add',
#  'FC/layer/2_1/dropout/Floor',
#  'FC/layer/2_1/dropout/div',
#  'FC/layer/2_1/dropout/mul',
#  'FC/layer/3_1/MatMul',
#  'FC/layer/3_1/H',
#  'FC/layer/3_1/Relu',
#  'FC/layer/3_1/dropout/Shape',
#  'FC/layer/3_1/dropout/random_uniform/min',
#  'FC/layer/3_1/dropout/random_uniform/max',
#  'FC/layer/3_1/dropout/random_uniform/RandomUniform',
#  'FC/layer/3_1/dropout/random_uniform/sub',
#  'FC/layer/3_1/dropout/random_uniform/mul',
#  'FC/layer/3_1/dropout/random_uniform',
#  'FC/layer/3_1/dropout/add',
#  'FC/layer/3_1/dropout/Floor',
#  'FC/layer/3_1/dropout/div',
#  'FC/layer/3_1/dropout/mul',
#  'FCFinal_1/MatMul',
#  'FCFinal_1/logits',
#  'FCFinal_1/Softmax',
#  'FCoptimize_2/Rank',
#  'FCoptimize_2/Shape',
#  'FCoptimize_2/Rank_1',
#  'FCoptimize_2/Shape_1',
#  'FCoptimize_2/Sub/y',
#  'FCoptimize_2/Sub',
#  'FCoptimize_2/Slice/begin',
#  'FCoptimize_2/Slice/size',
#  'FCoptimize_2/Slice',
#  'FCoptimize_2/concat/values_0',
#  'FCoptimize_2/concat/axis',
#  'FCoptimize_2/concat',
#  'FCoptimize_2/Reshape',
#  'FCoptimize_2/Rank_2',
#  'FCoptimize_2/Shape_2',
#  'FCoptimize_2/Sub_1/y',
#  'FCoptimize_2/Sub_1',
#  'FCoptimize_2/Slice_1/begin',
#  'FCoptimize_2/Slice_1/size',
#  'FCoptimize_2/Slice_1',
#  'FCoptimize_2/concat_1/values_0',
#  'FCoptimize_2/concat_1/axis',
#  'FCoptimize_2/concat_1',
#  'FCoptimize_2/Reshape_1',
#  'FCoptimize_2/SoftmaxCrossEntropyWithLogits',
#  'FCoptimize_2/Sub_2/y',
#  'FCoptimize_2/Sub_2',
#  'FCoptimize_2/Slice_2/begin',
#  'FCoptimize_2/Slice_2/size',
#  'FCoptimize_2/Slice_2',
#  'FCoptimize_2/Reshape_2',
#  'FCoptimize_2/Const',
#  'FCoptimize_2/Mean',
#  'FCoptimize_2/gradients/Shape',
#  'FCoptimize_2/gradients/Const',
#  'FCoptimize_2/gradients/Fill',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Reshape/shape',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Reshape',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Shape',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Tile',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Shape_1',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Shape_2',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Const',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Prod',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Const_1',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Prod_1',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Maximum/y',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Maximum',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/floordiv',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/Cast',
#  'FCoptimize_2/gradients/FCoptimize_2/Mean_grad/truediv',
#  'FCoptimize_2/gradients/FCoptimize_2/Reshape_2_grad/Shape',
#  'FCoptimize_2/gradients/FCoptimize_2/Reshape_2_grad/Reshape',
#  'FCoptimize_2/gradients/zeros_like',
#  'FCoptimize_2/gradients/FCoptimize_2/SoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim',
#  'FCoptimize_2/gradients/FCoptimize_2/SoftmaxCrossEntropyWithLogits_grad/ExpandDims',
#  'FCoptimize_2/gradients/FCoptimize_2/SoftmaxCrossEntropyWithLogits_grad/mul',
#  'FCoptimize_2/gradients/FCoptimize_2/Reshape_grad/Shape',
#  'FCoptimize_2/gradients/FCoptimize_2/Reshape_grad/Reshape',
#  'FCoptimize_2/gradients/FCFinal_1/logits_grad/BiasAddGrad',
#  'FCoptimize_2/gradients/FCFinal_1/logits_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FCFinal_1/logits_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FCFinal_1/logits_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FCFinal_1/MatMul_grad/MatMul',
#  'FCoptimize_2/gradients/FCFinal_1/MatMul_grad/MatMul_1',
#  'FCoptimize_2/gradients/FCFinal_1/MatMul_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FCFinal_1/MatMul_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FCFinal_1/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/Shape',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/Shape_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/mul',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/Sum',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/Reshape',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/mul_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/Sum_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/Reshape_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/Shape',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/Shape_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/RealDiv',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/Sum',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/Reshape',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/Neg',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/RealDiv_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/RealDiv_2',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/mul',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/Sum_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/Reshape_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FC/layer/3_1/dropout/div_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/Relu_grad/ReluGrad',
#  'FCoptimize_2/gradients/FC/layer/3_1/H_grad/BiasAddGrad',
#  'FCoptimize_2/gradients/FC/layer/3_1/H_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FC/layer/3_1/H_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FC/layer/3_1/H_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/MatMul_grad/MatMul',
#  'FCoptimize_2/gradients/FC/layer/3_1/MatMul_grad/MatMul_1',
#  'FCoptimize_2/gradients/FC/layer/3_1/MatMul_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FC/layer/3_1/MatMul_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FC/layer/3_1/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/Shape',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/Shape_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/mul',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/Sum',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/Reshape',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/mul_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/Sum_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/Reshape_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/Shape',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/Shape_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/RealDiv',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/Sum',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/Reshape',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/Neg',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/RealDiv_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/RealDiv_2',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/mul',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/Sum_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/Reshape_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FC/layer/2_1/dropout/div_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/Relu_grad/ReluGrad',
#  'FCoptimize_2/gradients/FC/layer/2_1/H_grad/BiasAddGrad',
#  'FCoptimize_2/gradients/FC/layer/2_1/H_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FC/layer/2_1/H_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FC/layer/2_1/H_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/MatMul_grad/MatMul',
#  'FCoptimize_2/gradients/FC/layer/2_1/MatMul_grad/MatMul_1',
#  'FCoptimize_2/gradients/FC/layer/2_1/MatMul_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FC/layer/2_1/MatMul_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FC/layer/2_1/MatMul_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/Shape',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/Shape_1',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/BroadcastGradientArgs',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/mul',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/Sum',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/Reshape',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/mul_1',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/Sum_1',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/Reshape_1',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/tuple/group_deps',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/tuple/control_dependency',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/mul_grad/tuple/control_dependency_1',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/Shape',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/Shape_1',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/BroadcastGradientArgs',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/RealDiv',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/Sum',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/Reshape',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/Neg',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/RealDiv_1',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/RealDiv_2',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/mul',
#  'FCoptimize_2/gradients/FC/layer/1_1/dropout/div_grad/Sum_1',
#  ...]
